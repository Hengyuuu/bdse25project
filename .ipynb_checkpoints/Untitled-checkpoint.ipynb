# %%
import requests
from bs4 import BeautifulSoup
import csv
import random, time

headers = {"Referer": "https://www.104.com.tw/job/6vrlf"}
response = requests.get('https://www.104.com.tw/job/7ie6i?jobsource=jolist_d_relevance', headers = headers)
soup = BeautifulSoup(response.text,'html.parser')

job_content = soup.find('p', class_='job-description__content').text
# job_content = soup.find('div', attrs={'job-description__content'})
# job_exprience = soup.find('div', class_='col p-0 list-row_data').find('p').text
job_exprience = soup.find('p', class_= 't3 mb-0').text

# print(job_exprience)

# %%
print(soup.select("div > p "))
# print(job_content)
# Out:
# [<p> </p>, <p><a class="more" href="#" onclick="sendToMy104(19,0,1);return false;">請先登入會員</a></p>, <p> </p>, <p><a class="more" href="#" onclick="sendToMy104(20,0,1);return false;">請先登入會員</a></p>, <p> </p>, <p><a class="more" href="#" onclick="sendToMy104(14,0,1);return false;">請先登入會員</a></p>, <p class="mb-5 r3 job-description__content text-break" data-v-3ff52466="" data-v-53f58661="">
# 資訊工程相關科系畢業者優先、無工作經驗可。
#
# 1.工作內容：
#    ●後端 server 應用程式撰寫設計與開發。
#    ●開發流程文件撰寫。
#    ●資料庫建置與維護。
#    ●依專案安排工作事項。
#
# 2.相關技能：
#    ● JAVA（必要）、Python、JavaScript、TypeScrip。
#    ●RDBMS(PostgreSQL、MySQL、SQL Sever...擇一必要）。
#    ●NoSQL(Redis, MongoDB...)。
#    ●Git（必要）。
#
# 3.加分條件：
#    ●熟悉docker、k8s、linux/unix shell。
#
# 4.工作態度積極、負責、具良好分析與解決問題之能力、願意主動學習並
#    重視團隊合作。
#
# 5.薪資3.5萬-6萬，依資歷面議。</p>, <p class="t3 mb-0" data-v-306b2a3c=""> <div class="category-item col p-0 job-description-table__data" data-v-1fdb5194="" data-v-306b2a3c="" data-v-53f58661=""><div class="t3 mb-0 identity-type d-inline-block align-bottom" data-v-1fdb5194=""><div class="v-popover" data-gtm-content="職務類別" data-v-1fdb5194=""><div aria-describedby="popover_7tqcej8dwd" class="trigger" style="display: inline-block;"><u data-v-1fdb5194="">通訊軟體工程師</u></div> </div><span class="d-none" data-v-1fdb5194=""> 認識通訊軟體工程師職務 <ul data-v-1fdb5194=""><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - joblist" data-v-1fdb5194="" href="//www.104.com.tw/jobs/search/?cat=2007001003"> 更多通訊軟體工程師相關工作 </a></li><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - 診所" data-v-1fdb5194="" href="//giver.104.com.tw/questionList/2007001003?utm_source=104&amp;utm_medium=cweb_job_jcat"> 通訊軟體工程師-求職面試工作問題 </a></li><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - nabi" data-v-1fdb5194="" href="//nabi.104.com.tw/cjcat/2007001003/?utm_source=pcjob_page&amp;utm_medium=cjcat"> 企業普遍要求的技能、能力和薪資 </a></li></ul></span><span data-v-1fdb5194="">、</span></div><div class="t3 mb-0 identity-type d-inline-block align-bottom" data-v-1fdb5194=""><div class="v-popover" data-gtm-content="職務類別" data-v-1fdb5194=""><div aria-describedby="popover_uhnvd7qb6y" class="trigger" style="display: inline-block;"><u data-v-1fdb5194="">軟體設計工程師</u></div> </div><span class="d-none" data-v-1fdb5194=""> 認識軟體設計工程師職務 <ul data-v-1fdb5194=""><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - joblist" data-v-1fdb5194="" href="//www.104.com.tw/jobs/search/?cat=2007001004"> 更多軟體設計工程師相關工作 </a></li><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - 診所" data-v-1fdb5194="" href="//giver.104.com.tw/questionList/2007001004?utm_source=104&amp;utm_medium=cweb_job_jcat"> 軟體設計工程師-求職面試工作問題 </a></li><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - nabi" data-v-1fdb5194="" href="//nabi.104.com.tw/cjcat/2007001004/?utm_source=pcjob_page&amp;utm_medium=cjcat"> 企業普遍要求的技能、能力和薪資 </a></li></ul></span><span data-v-1fdb5194="">、</span></div><div class="t3 mb-0 identity-type d-inline-block align-bottom" data-v-1fdb5194=""><div class="v-popover" data-gtm-content="職務類別" data-v-1fdb5194=""><div aria-describedby="popover_hdnygw8rjs" class="trigger" style="display: inline-block;"><u data-v-1fdb5194="">Internet程式設計師</u></div> </div><span class="d-none" data-v-1fdb5194=""> 認識Internet程式設計師職務 <ul data-v-1fdb5194=""><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - joblist" data-v-1fdb5194="" href="//www.104.com.tw/jobs/search/?cat=2007001006"> 更多Internet程式設計師相關工作 </a></li><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - 診所" data-v-1fdb5194="" href="//giver.104.com.tw/questionList/2007001006?utm_source=104&amp;utm_medium=cweb_job_jcat"> Internet程式設計師-求職面試工作問題 </a></li><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - nabi" data-v-1fdb5194="" href="//nabi.104.com.tw/cjcat/2007001006/?utm_source=pcjob_page&amp;utm_medium=cjcat"> 企業普遍要求的技能、能力和薪資 </a></li></ul></span><!-- --></div></div></p>, <p class="t3 mb-0" data-v-306b2a3c=""> <p class="t3 mb-0 mr-2 text-primary font-weight-bold align-top d-inline-block" data-v-306b2a3c="" data-v-53f58661=""> 月薪35,000~60,000元 </p><!-- --></p>, <p class="t3 mb-0" data-v-306b2a3c=""> 全職 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> <div addressno="6001002003" businesstrip="無需出差外派" class="job-address" data-v-306b2a3c="" data-v-53f58661="" data-v-5ee8db26="" delegatedrecruit="" hiretype="0" jobcategory="[object Object],[object Object],[object Object]" jobdescription="
# 資訊工程相關科系畢業者優先、無工作經驗可。
#
# 1.工作內容：
#    ●後端 server 應用程式撰寫設計與開發。
#    ●開發流程文件撰寫。
#    ●資料庫建置與維護。
#    ●依專案安排工作事項。
#
# 2.相關技能：
#    ● JAVA（必要）、Python、JavaScript、TypeScrip。
#    ●RDBMS(PostgreSQL、MySQL、SQL Sever...擇一必要）。
#    ●NoSQL(Redis, MongoDB...)。
#    ●Git（必要）。
#
# 3.加分條件：
#    ●熟悉docker、k8s、linux/unix shell。
#
# 4.工作態度積極、負責、具良好分析與解決問題之能力、願意主動學習並
#    重視團隊合作。
#
# 5.薪資3.5萬-6萬，依資歷面議。" jobtype="1" latitude="25.0216059" longitude="121.4684116" manageresp="不需負擔管理責任" needemp="不限" salary="月薪35,000~60,000元" salarymax="60000" salarymin="35000" salarytype="50" startworkingday="不限" vacationpolicy="週休二日" workperiod="日班" worktype=""><span data-v-5ee8db26=""> 新北市板橋區民生路二段239號17樓 </span><!-- --><span class="t4" data-v-5ee8db26=""> (距捷運新埔站290公尺) </span><!-- --><a class="mx-1" data-v-5ee8db26="" href="https://maps.google.com.tw/?q=昇晉整合服務有限公司@25.0216059,121.4684116&amp;z=17" rel="noopener" target="_blank"><i class="jb_icon_location text-primary" data-gtm-content="地圖連結" data-v-5ee8db26=""></i></a></div></p>, <p class="t3 mb-0" data-v-306b2a3c=""> </p>, <p class="t3 mb-0" data-v-306b2a3c=""> 不需負擔管理責任 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> 無需出差外派 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> 日班 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> 週休二日 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> 不限 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> 不限 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> 不拘 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> 專科以上 </p>, <p class="t3 mb-0" data-v-306b2a3c="">   不拘 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> <p class="t3 m-0" data-v-306b2a3c="" data-v-5c24eae0=""> 不拘 </p></p>, <p class="t3 mb-0" data-v-306b2a3c="">   不拘 </p>, <p class="t3 mb-0" data-v-306b2a3c="">   不拘 </p>, <p class="t3 mb-0" data-v-306b2a3c=""> <div class="col p-0 job-requirement-table__data" data-v-306b2a3c="" data-v-5c24eae0=""><p class="t3 m-0" data-v-306b2a3c="" data-v-5c24eae0="">未填寫</p></div></p>, <p class="t3 m-0" data-v-306b2a3c="" data-v-5c24eae0="">未填寫</p>, <p class="r3 mb-0 text-break" data-v-3b31bcb6="" data-v-3ff52466="">
# 公司福利制度
#
# ◆ 分紅 / 配股
#    1.員工紅利
#
# ◆ 獎金 / 禮品類
#    1.年終獎金
#    2.年節禮金
#
# ◆ 保險類
#    1.勞健保、提繳退休金、職災保險
#    2.員工團體保險
#    3.員工旅遊旅平險
#
# ◆ 休閒類
#    1.員工旅遊
#    2.尾牙、春酒
#
# ◆ 制度類
#    1.加班費
#    2.績效獎金
#
# ◆ 請 / 休假制度
#    1.週休二日
#    2.特休、年假
#    3.不扣薪病假
#    4.不扣薪事假
#    5.家庭照顧假
#    6.生理假
#
#  ◆ 其他
#    1.員工健檢
#    2.教育訓練
#    3.電腦設備提供
#    4.免費咖啡、零食
#
# ◆ 補助類
#    1.結婚禮金
#    2.生育禮金</p>, <p class="t4 m-0" data-v-1ec4ab07="" data-v-3ff52466=""> 104人力銀行提醒您 </p>, <p class="t4 m-0" data-v-1ec4ab07="" data-v-3ff52466=""> 履歷關閉時仍可投遞履歷喔！面試時請遵守求職禮儀準時赴約並小心安全 </p>, <p class="h2 jb-link jb-link-blue jb-link-blue--visited" data-v-f8ff6c20=""> 夜班募集─工程/品保/倉儲/製造，high薪招募 </p>, <p class="jb-link jb-link-blue jb-link-blue--visited mr-5 h4" data-v-f8ff6c20=""> 【2021年Forbes最佳雇主】讓微星照顧您~ </p>, <p class="h2 header__title mr-1" data-v-562239ea="" data-v-588d131b=""> 我適合這份工作嗎 </p>]
