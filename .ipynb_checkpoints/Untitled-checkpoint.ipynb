# %%
import requests
from bs4 import BeautifulSoup
import csv
import random, time

headers = {"Referer": "https://www.104.com.tw/job/6vrlf"}
response = requests.get('https://www.104.com.tw/job/7e00i?jobsource=jolist_a_relevance', headers = headers)
soup = BeautifulSoup(response.text,'html.parser')

job_content = soup.find('p', class_='job-description__content').text
# job_content = soup.find('div', attrs={'job-description__content'})
# job_exprience = soup.find('div', class_='col p-0 list-row_data').find('p').text
job_exprience = soup.find('p', class_= 't3 mb-0').text

# print(job_exprience)

# %%
# y = soup.find_all('h3', class_= 'h3')['p']
x = soup.find_all('div', class_= 'dialog container-fluid bg-white rounded job-requirement mb-4 pt-6 pb-6')
goodat = soup.find_all('a', class_='tools')
other = soup.find_all('p', class_='m-0 r3 w-100') #其他條件

for i in x:
    print(i.p.text.strip())#工作經歷
    print(i.find_all('p')[1].text.strip())#學歷要求
    print(i.find_all('p')[2].text.strip())#科系要求
for i in goodat:
    print(i.text) # 擅長工具

for i in other:
    print(i.text)

# for i in y:
    # print(i.text)
# Out:
# 3年以上
# 大學以上
# 不拘
# ASP.NET
# C#
# 1. 理解 OOP, SOLID, DDD 等設計模式與準則並熟練使⽤。
# 2. 具單元測試概念與能有效運⽤提升 API 品質。
# 3. 熟悉 Docker 等容器服務。
# 4. 具 CI/CD 架設能⼒。
# 5. 能將 RDBMS 與 NoSQL 使⽤在適合的場景並優化其效能。
# 6. 善⽤ redis, kafka 以進⾏後端服務快取。
