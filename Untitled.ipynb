# %%
import requests
from bs4 import BeautifulSoup
import csv
import random, time

headers = {"Referer": "https://www.104.com.tw/job/6vrlf"}
response = requests.get('https://www.104.com.tw/job/775l2?jobsource=hotjob_chr', headers = headers)
soup = BeautifulSoup(response.text,'html.parser')

job_content = soup.find('p', class_='job-description__content').text
job_require = soup.find_all('div', class_= 'dialog container-fluid bg-white rounded job-requirement mb-4 pt-6 pb-6')

# print(job_exprience)

# %%
print(job_content)
# Out:
# 1. 負責資訊系統之程式開發、單元測試撰寫、功能測試
# 2. 負責資料庫程式開發與維護
# 3. 負責系統開發相關文件撰寫
# 4. 負責系統維護管理與功能更新
# 5. 負責程式資安議題處理及修正
# 6. 其他主管交辦事項
#
# 104僅供職缺參考，若您對此職缺有興趣，請至本行「玉山菁英甄選網站」投遞履歷，如書審通過，後續將邀請您參加面談。謝謝！
# 【網址：https://esnhr.pse.is/394b2n】

# %%
# y = soup.find_all('h3', class_= 'h3')['p']
x = soup.find_all('div', class_= 'dialog container-fluid bg-white rounded job-requirement mb-4 pt-6 pb-6')
goodat_all = soup.find_all('a', class_='tools')
other = soup.find_all('p', class_='m-0 r3 w-100') #其他條件

# for i in x:
#     print(i.p.text.strip())#工作經歷
#     print(i.find_all('p')[1].text.strip())#學歷要求
#     print(i.find_all('p')[2].text.strip())#科系要求
# for i in goodat_all:
#     print(i.text) # 擅長工具
job_goodat1 = []
for i in goodat_all:
    job_goodat = i.text #擅長工具
    job_goodat1.append(job_goodat)

print(job_goodat1)

# for i in other:
#     print(i.text)

# for i in y:
    # print(i.text)
# Out:
# ['Python', 'MySQL', 'Tableau', 'Power BI\u200b']

# %%
job_goodat1 = []
for i in goodat_all:
    job_goodat = i.text #擅長工具
    job_goodat1.append(job_goodat)

print(job_goodat1)
# Out:
# ['Python', 'MySQL', 'Tableau', 'Power BI\u200b']
