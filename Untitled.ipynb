# %%
import requests
from bs4 import BeautifulSoup
import csv
import random, time

headers = {"Referer": "https://www.104.com.tw/job/6vrlf"}
response = requests.get('https://www.104.com.tw/job/7ie6i?jobsource=jolist_d_relevance', headers = headers)
soup = BeautifulSoup(response.text,'html.parser')

job_content = soup.find('p', class_='job-description__content').text
# job_content = soup.find('div', attrs={'job-description__content'})
# job_exprience = soup.find('div', class_='col p-0 list-row_data').find('p').text
job_exprience = soup.find('p', class_= 't3 mb-0').text

print(job_exprience)
<div data-v-306b2a3c="" class="list-row__data"><p data-v-306b2a3c="" class="t3 mb-0"> 不拘 </p></div>
# Out:
#  通訊軟體工程師  認識通訊軟體工程師職務  更多通訊軟體工程師相關工作  通訊軟體工程師-求職面試工作問題  企業普遍要求的技能、能力和薪資 、軟體設計工程師  認識軟體設計工程師職務  更多軟體設計工程師相關工作  軟體設計工程師-求職面試工作問題  企業普遍要求的技能、能力和薪資 、Internet程式設計師  認識Internet程式設計師職務  更多Internet程式設計師相關工作  Internet程式設計師-求職面試工作問題  企業普遍要求的技能、能力和薪資

# %%
print(soup.find('div', class_='list-row__data'))
# Out:
# <div class="col p-0 list-row__data" data-v-306b2a3c=""><p class="t3 mb-0" data-v-306b2a3c=""> <div class="category-item col p-0 job-description-table__data" data-v-1fdb5194="" data-v-306b2a3c="" data-v-53f58661=""><div class="t3 mb-0 identity-type d-inline-block align-bottom" data-v-1fdb5194=""><div class="v-popover" data-gtm-content="職務類別" data-v-1fdb5194=""><div aria-describedby="popover_7tqcej8dwd" class="trigger" style="display: inline-block;"><u data-v-1fdb5194="">通訊軟體工程師</u></div> </div><span class="d-none" data-v-1fdb5194=""> 認識通訊軟體工程師職務 <ul data-v-1fdb5194=""><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - joblist" data-v-1fdb5194="" href="//www.104.com.tw/jobs/search/?cat=2007001003"> 更多通訊軟體工程師相關工作 </a></li><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - 診所" data-v-1fdb5194="" href="//giver.104.com.tw/questionList/2007001003?utm_source=104&amp;utm_medium=cweb_job_jcat"> 通訊軟體工程師-求職面試工作問題 </a></li><li data-v-1fdb5194=""><a data-gtm-content="職務小卡 - nabi" data-v-1fdb5194="
# ...
