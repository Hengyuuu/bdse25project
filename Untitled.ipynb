# %%
import requests
from bs4 import BeautifulSoup
import csv
import random, time

headers = {"Referer": "https://www.104.com.tw/job/6vrlf"}{"Referer": "https://www.104.com.tw/job/6vrlf"}
response = requests.get('https://www.104.com.tw/job/4n49v?jobsource=hotjob_chr', headers = headers)
soup = BeautifulSoup(response.text,'html.parser')

job_content = soup.find('p', class_='job-description__content').text
job_require = soup.find_all('div', class_= 'dialog container-fluid bg-white rounded job-requirement mb-4 pt-6 pb-6')

# print(job_exprience)

# %%
print(job_content)
# Out:
# 公司內部使用Gulp為主要開發工具, 我們期待新的夥伴除了基本Html開發外也能有處理前端框架之經驗(Vue or Angular), 如你對自己的前端技術有熱誠且具備不斷磨連自己與我們同仁一起成長的企圖心, 非常歡迎你來與我們詳談！
#
# 【基本技術】
# 需熟悉HTML5，CSS3與Javascript基本之網站技術，RWD處理能力，獨力完成基本技術之網站開發需求
#
# 【瀏覽器兼容性版面調整經驗】
# 瀏覽器包含了 IE、Edge、Chrome、FireFox、Safari...等，能依循專案需求針對瀏覽器調整相對應的程式碼撰寫，讓畫面能在瀏覽器上呈現相同的視覺成果 (當然瀏覽器本身有限制的情況下除外)，同時也需要注意瀏覽器相容性等問題
#
# 【與前端夥伴們一同成長】
# 我們期待技術人員都能關注網站前端技術、行動應用及網路發展趨勢，一同分享新技術以及協助公司其他部門的夥伴在專業知識上的安排及判斷
#
# 【重視使用經驗細節與優化】
# 海棠設計非常重視視覺設計之成果是否有一定的品質於網站畫面中呈現，我們致力於提供給客戶最好的設計品質以及適合的網頁互動設計
#
# 【樣式框架之經驗】
# 樣式框架如 bootstrap 、foundation，是我們經常使用之樣式框架，期待你對 bootstrap 以及 foundation 能有基本的認知與使用概念
#
# 【Git使用經驗與概念理解】
# 你會與前端同仁、後端人員一同開發、協作專案，因此須具備Git版控使用經驗及概念，如你與我們使用之軟體不同沒關係，可以一同討論分享 (會以海棠目前使用之工具為主)
#
# 【SEO相關細節】
# 專案中一定需配置SEO相關項目，且須具備SEO需處理之項目理解能力及執行能力
#
# 【與後端對話之能力】
# 解析RESETFUL API與後端工程師協作串接資料，欄位的建置與設計上皆須利於後端開發，如需調整，也需具備與後端工程師溝通達成共識解決問題之能力
#
# 【良好的溝通與傾聽】
# 每個人皆有自己工作的一套模式，我們期待公司的每一位夥伴都能有培養溝通能力以及傾聽夥伴的意見與想法
#
# 面試請務必附上作品或個人網站連結向我們分享你的精彩作品，
# 期待與你相識，一同成長與進步。

# %%
# y = soup.find_all('h3', class_= 'h3')['p']
x = soup.find_all('div', class_= 'dialog container-fluid bg-white rounded job-requirement mb-4 pt-6 pb-6')
goodat_all = soup.find_all('a', class_='tools')
other = soup.find_all('p', class_='m-0 r3 w-100') #其他條件

# for i in x:
#     print(i.p.text.strip())#工作經歷
#     print(i.find_all('p')[1].text.strip())#學歷要求
#     print(i.find_all('p')[2].text.strip())#科系要求
# for i in goodat_all:
#     print(i.text) # 擅長工具
job_goodat1 = []
for i in goodat_all:
    job_goodat = i.text #擅長工具
    job_goodat1.append(job_goodat)

print(job_goodat1)

# for i in other:
#     print(i.text)

# for i in y:
    # print(i.text)
# Out:
# ['Python', 'MySQL', 'Tableau', 'Power BI\u200b']

# %%
job_goodat1 = []
for i in goodat_all:
    job_goodat = i.text #擅長工具
    job_goodat1.append(job_goodat)

print(job_goodat1)
# Out:
# ['Python', 'MySQL', 'Tableau', 'Power BI\u200b']
