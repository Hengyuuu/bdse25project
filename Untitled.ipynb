# %%
import requests
from bs4 import BeautifulSoup
import csv
import random, time

headers = {"Referer": "https://www.104.com.tw/job/6vrlf"}
response = requests.get('https://www.104.com.tw/job/7mqgh?jobsource=jolist_d_relevance', headers = headers)
soup = BeautifulSoup(response.text,'html.parser')

job_content = soup.find('p', class_='job-description__content').text
job_require = soup.find_all('div', class_= 'dialog container-fluid bg-white rounded job-requirement mb-4 pt-6 pb-6')

# print(job_exprience)

# %%
print(job_content)
# Out:
# 身為 KKday 的資料科學家，你將會與世界各地的市場行銷團隊和產品經理合作，負責執行資料科學專案，引領數據驅動 KKday 成長營銷生態系，進而幫助 KKday 更快速成長。
#
# [ 你的工作包含 ]
# 1. 利用資料科學技術洞察客戶行為與社群數據，創造商業價值輔以行銷決策，會參與的主題包含：廣告、聯盟行銷、內容經營、會員標籤系統。
# 2. 具有獨立工作能力，能夠帶領執行需求訪談 (Requirement Collection)、資料收集 (Data Collection)、資料清理 (Data Cleaning) 、模型建置 (Model Creation)、資料視覺化 (Data Visualization) 等任務。
# 3. 維運與優化會員標籤 (CDP) 系統，並規劃 Roadmap。
# 4. 處理日常資料分析需求，與市場行銷團隊合作。
# 5. 和資料工程師與架構師合作，讓完成的專案符合 ETL/Data Pipeline、資料架構。

# %%
# y = soup.find_all('h3', class_= 'h3')['p']
x = soup.find_all('div', class_= 'dialog container-fluid bg-white rounded job-requirement mb-4 pt-6 pb-6')
goodat = soup.find_all('a', class_='tools')
other = soup.find_all('p', class_='m-0 r3 w-100') #其他條件

# for i in x:
#     print(i.p.text.strip())#工作經歷
#     print(i.find_all('p')[1].text.strip())#學歷要求
#     print(i.find_all('p')[2].text.strip())#科系要求
for i in goodat:
    print(i.text) # 擅長工具

# for i in other:
#     print(i.text)

# for i in y:
    # print(i.text)
# Out:
# Python
# MySQL
# Tableau
# Power BI​
